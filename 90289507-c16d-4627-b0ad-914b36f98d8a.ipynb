# %% [markdown]
# <div class="alert alert-success">
# <font size="5", color = "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Привет, Дмитрий :)
#
# Спасибо за работу на проекте, за все исправления и комментарии
#
# Стоит завершить фильтрацию данных.  На этапе предобработки стоит использовать больше разных гистограмм, чтобы оценить качество данных
#
# Стоит поправить итоговый вывод с учетом всех новых комментариев
#
# Подведем итоги, мы научились и повторили на проекте каким образом:
#
# + читать тех. задание проекта
# + исследовать неочищенные данные
# + выдвигать гипотезы о пропусках данных и заполнять их значениями
# + принимать решения об удалении некачественных данных
# + находить аномалии в данных и отделять редкие значения
# + соглашаться с наличием пропусков в данных и не забывать об их наличии при фильтрации
# + строить информативные визуализации
# + делить одну выборку на две части
# + находить зависимости и распределения в данных
# + формировать выводы
#
# Навыки отработаны, проект принят
#
# <b>Поздравляю с успешно сданным третьим проектом на факультете дата-аналитики Я.Практикум</b>
#
# <div class="alert alert-success">
#     <font size="5", color = "seagreen"><b>Успехов в дальнейшей учебе 🤝</b></font><br />
#
# добавил пример в п.4.5

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Привет, Дмитрий :) Спасибо за все исправления и комментарии
#
# Критические ❌ комментарии
#
# + настроить фильтрацию редких значений в п. 2.4, учесть нормальные значения и удалить остатки аномалий
# + добавить вывод в п. 4.3
# + исследовать аномалии в п.4.5
# + поправить итоговый вывод
#
# добавил подсказки и бонус
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5"><b>Жду твой проект и твои комментарии 🤝</b></font><br />
#
# нумерация пунктов из брифа проекта, у тебя они могут быть другие

# %% [markdown]
# <div class="alert alert-success">
# <font size="4"><b>Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Привет, Дмитрий :) Спасибо, что прислал задание :) Меня зовут Ринат Хисамов и я буду проверять твой проект. Предлагаю обращаться друг к другу на ты. Так нам будет гораздо проще и удобней общаться
#
# Мои комментарии обозначены пометкой <b>Комментарий ревьюера</b>. Далее в файле сможешь найти их в похожих ячейках (если фон комментария зелёный — всё сделано правильно (✔️), рекомендации таким же цветом. Отдельным цветом — блок ссылок (примеры ниже, 🍕). Оранжевым или светло желтым рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше. (⚠️); <u> красный комментарий</u>: код, график или вывод стоит переделать (❌)).
#
# Не удаляй все эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
# Будет замечательно, если добавишь свои комментарии и пояснения✍
#
# Поехали 🚀
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# <div style="border:solid steelblue 1px; padding: 20px">
#
# <font size="4"><p style="text-align:center"><b>Примеры комментариев </b></p></font>
#
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4"><b>🍕 Пример комментария - совета, здесь м.б. просто ссылка</b></font>
#     <br />
#         <font size="3", color = "black">
# <br />
#     Тут всего такого разного и вкусного :), есть способы прокачать проект визуализациями (ценит большинство "боссов")  <br /><br />
#         <a href="https://pyprog.pro/mpl/mpl_short_guide.html">Краткое руководство по Matplotlib</a>
#         На сайте много полезных материалов, мне самому очень помогло в свое время, до сих пор подсматриваю :)
#
#
# </div>
#
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
#     <font size="3"><b>⚠️ Пример оформления некритичного комментария</b>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Рекомендации, которые, хоть и не обязательны, но точно сделают ревью лучше
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-danger">
# <font size="3"><b>❌ Пример оформления комментария к блоку(строке) программного кода (или выводу), который стоит переделать</b></font>
#     <br />
#     <font size="2", color = "black">
# <br />
#     Отправлен не тот проект, напиши в своих комментариях, что случилось? жду — <b>это пример</b>
#     <br />
#     </font>
#
# </div>
#
# <div class="alert alert-success">
# <font size="4"><b>✔️ Пример оформления комментария, который нравится большинству студентов</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#     Круто, молодец, отлично, логично, или — 👌, 👍, или — выводы отвечают на все вопросы к данным и проекту
#     <br />
#     </font>
#
# </div>

# %% [markdown]
# # Для твоих вопросов или комментариев оставлю такую ячейку, чтобы было удобнее взаимодействовать на проекте

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> ... , вот мой вопрос ...
#         На счет физического смысла , я хотел найти среднюю стоимость каждого киллометра , но у меня почему стало вмето значения писать inf это 4.5
#         Так же в 4.5 иследователь аномалии , от них нужно будет избавиться ?
#         И остался там еще вывод общий , я его поправлю , как 4.5 сделаю
#         Но главная просьюа в другом , я уже не много запутался по проекту , и немного забывался и мог забыть что поправлял , можете ещё раз пройтись , вроде соталось только с пунктом 4.5

# %% [markdown]
# <div class="alert alert-info">
# <font size="4", color = "black"><b>✍ Комментарий студента в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Спасибо большое за бонус , очень крутые графики!С новыми комментами все больше начинаю понимать своих ошибки и их глупость.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Оставил подсказку про 4.5
#
# Аномалии стоит исследовать - так мы учимся групировать данные или строить  сводные таблицы, обновленный перечень комментариев добавил

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Название, краткое вступление в работу и главная задача зафиксированы.
#
# Четкий план работ и перечень основных задач позволит коллегам быстрее вникнуть в суть проекта, + будет легче  идти к главной цели проекта

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию.

# %%
import pandas as pd #импортируем библиотеку Pandas
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Молодец, что делишь блоки загрузки библиотек и датасета, в случае необходимости добавления новых библиотек не придется загружать весь датасет заново и перезапускать проект целиком

# %%
data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')

# %%
data.info() #изучим общую информацию о наших данныхи
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
display(data.head(10))#выведем первый 10 строк нашей таблицы
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1             7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2            10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3             0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4             2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5            10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6             6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7             5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8            20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9            18   5400000.0       61.00  2017-02-26T00:00:00      3
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0        51.00      8          NaN  ...
# 1             NaN          11.0        18.60      1          NaN  ...
# ...

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ <b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br /> display() вместо print(), поможет навести красоту на проекте

# %% [markdown]
# Как видно из первых 10 строк , в некоторых столбцах есть пропушенные значения , так же по мимо этого видно что есть стоблцы в названия , которых написаны не в змеином регистре.

# %%
data.hist(figsize=(15,20)); #построим общую гистограмму для всех числовых столбцов нашего датафрейма

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
# Убрать служ. информацию поможет точка с запятой на посл. строке кода
#
#     array([[<AxesSubplot:title={'center':'total_images'}>,
#         <AxesSubplot:title={'center':'last_price'}>,
#         <AxesSubplot:title={'center':'total_area'}>,
#         <AxesSubplot:title={'center':'rooms'}>],
#        [<AxesSubplot:title={'center':'ceiling_height'}>,
#         <AxesSubplot:title={'center':'floors_total'}>,
#         <AxesSubplot:title={'center':'living_area'}>,
#         <AxesSubplot:title={'center':'floor'}>],
#        [<AxesSubplot:title={'center':'kitchen_area'}>,
#         <AxesSubplot:title={'center':'balcony'}>,
#         <AxesSubplot:title={'center':'airports_nearest'}>,
#         <AxesSubplot:title={'center':'cityCenters_nearest'}>],
#        [<AxesSubplot:title={'center':'parks_around3000'}>,
#         <AxesSubplot:title={'center':'parks_nearest'}>,
#         <AxesSubplot:title={'center':'ponds_around3000'}>,
#         <AxesSubplot:title={'center':'ponds_nearest'}>],
#        [<AxesSubplot:title={'center':'days_exposition'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)
#
# data.hist(figsize=(15, 20));

# %%
data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23699.000000  2.369900e+04  23699.000000  23699.000000    14504.000000
# mean       9.858475  6.541549e+06     60.348651      2.070636        2.771499
# std        5.682529  1.088701e+07     35.654083      1.078405        1.261056
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.520000
# 50%        9.000000  4.650000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.800000e+06     69.900000      3.000000        2.800000
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23613.000000  21796.000000  23699.000000  21421.000000  12180.000000
# mean      10.673824     34.457852      5.892358     10.569807      1.150082
# ...

# %% [markdown]
# Придется поработать с данными , так как уже можно увидеть аномальные значения. Например максимальное значения высота потолков равная "100".

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> обзор данных проведен корректно

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# #### Изучим пропущенные значения в столбцах.

# %%
data.isnull().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# У нас достаточно много пропушенных значений.

# %%
# check
# пропущенные значения бары

def pass_value_barh(df):
    try:
        (
            (df.isna().mean()*100)
            .to_frame()
            .rename(columns = {0:'space'})
            .query('space > 0')
            .sort_values(by = 'space', ascending = True)
            .plot(kind = 'barh', figsize = (19,6), rot = -5, legend = False, fontsize = 16)
            .set_title('Пример' + "\n", fontsize = 22, color = 'SteelBlue')    
        );    
    except:
        print('пропусков не осталось :) ')

# %%
pass_value_barh(data)

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br /> Наглядность представления информации одна из важных составляющих работы дата-аналитика или дата-сайентиста

# %% [markdown]
# У нас есть пропуски в столбце "is_apartment", они связаны с тем , что пользователь решил не вносить данные , так как это не апартаменты

# %%
data['is_apartment']=data['is_apartment'].fillna(0)

# %% [markdown]
# Так же у нас есть пропуски в столбце "balcony", заполним их "0"

# %%
data['balcony']=data['balcony'].fillna(0)

# %% [markdown]
# Заполним пропуски в столбце "parks_around3000", видимо парков в радиусе 3км нет и пользователь решил не заполнять занные

# %%
data['parks_around3000']=data['parks_around3000'].fillna(0)

# %% [markdown]
# Такая же ситуация у нас и с количеством водоемов в радиусе 3км

# %%
data['ponds_around3000']=data['ponds_around3000'].fillna(0)

# %% [markdown]
# Удалим строки с пустыми значениями в столбце 'locality_name', так как нам не нужны квартиры без их местоположения. Так же поступим с столбцом 'floors_total', у нас в них не так много пропусков и на результат это не повлияет.

# %%
data=data.dropna(subset=['locality_name', 'floors_total'])

# %% [markdown]
# Проверим датафрейм ещё раз на пропуски , убедившись что заполнили пустые значения

# %%
data.isnull().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9084
# floors_total                0
# living_area              1865
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area             2222
# balcony                     0
# locality_name               0
# airports_nearest         5524
# cityCenters_nearest      5501
# parks_around3000            0
# parks_nearest           15535
# ponds_around3000            0
# ponds_nearest           14529
# days_exposition          3171
# dtype: int64

# %% [markdown]
# #### Рассмотрим типы данных в каждом столбце

# %%
data.dtypes
# Out:
# total_images              int64
# last_price              float64
# total_area              float64
# first_day_exposition     object
# rooms                     int64
# ceiling_height          float64
# floors_total            float64
# living_area             float64
# floor                     int64
# is_apartment             object
# studio                     bool
# open_plan                  bool
# kitchen_area            float64
# balcony                 float64
# locality_name            object
# airports_nearest        float64
# cityCenters_nearest     float64
# parks_around3000        float64
# parks_nearest           float64
# ponds_around3000        float64
# ponds_nearest           float64
# days_exposition         float64
# dtype: object

# %% [markdown]
# Поменяем тип данных в столбце "last_price", так как больша стоимость квартир

# %%
data['last_price']=data['last_price'].astype('int')

# %% [markdown]
# Поменяем тип данных в столбце "balcony", так как количество балкон может быть только целым числом

# %%
data['balcony']=data['balcony'].astype('int')

# %% [markdown]
# Поменяем тип данных в столбце "parks_around3000", так как количество парков может быть только целое число

# %%
data['parks_around3000']=data['parks_around3000'].astype('int')

# %% [markdown]
# Поменяем тип данных в столбце "ponds_around3000", так как число водоем может быть только целое число

# %%
data['ponds_around3000']=data['ponds_around3000'].astype('int')

# %% [markdown]
# Поменяем тип данных в столбце "floors_total", количество этажей это целое число

# %%
data['floors_total']=data['floors_total'].astype('int')

# %% [markdown]
# Поменяем тип данных в столбце "first_day_exposition", так в данном столбце содержиться дата.

# %%
data['first_day_exposition']=pd.to_datetime(data['first_day_exposition'], format='%Y%m%dT%H:%M:%S')

# %% [markdown]
# Убедимся что исправили тип данных

# %%
data.dtypes
# Out:
# total_images                     int64
# last_price                       int64
# total_area                     float64
# first_day_exposition    datetime64[ns]
# rooms                            int64
# ceiling_height                 float64
# floors_total                     int64
# living_area                    float64
# floor                            int64
# is_apartment                    object
# studio                            bool
# open_plan                         bool
# kitchen_area                   float64
# balcony                          int64
# locality_name                   object
# airports_nearest               float64
# cityCenters_nearest            float64
# parks_around3000                 int64
# parks_nearest                  float64
# ponds_around3000                 int64
# ponds_nearest                  float64
# days_exposition                float64
# dtype: object

# %% [markdown]
# #### Изучим уникальные значения столбца "locality_name"

# %%
data['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'посёлок Шушары', 'городской посёлок Янино-1',
#        'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина', 'поселок Мурино',
#        'деревня Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'посёлок Металлострой',
#        'посёлок городского типа Лебяжье',
#        'посёлок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'посёлок Аннино',
#        'поселок городского типа Ефимовский', 'посёлок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
# ...

# %% [markdown]
# Есть разные обозначени одних и тех же населенных пунктов, попробуем это исправить

# %% [markdown]
# Так как у нас имеются такие названия как "поселок" и "посёлок" , заменим букву "ё" на "е".
# Так же изменим наименнования поселков.

# %%
data['locality_name']=data['locality_name'].str.replace('ё', 'е', regex=True)
data['locality_name']=data['locality_name'].str.replace('поселок городского типа', 'поселок', regex=True)
data['locality_name']=data['locality_name'].str.replace('городской поселок', 'поселок', regex=True)


#Проверим ли изменились данные
data['locality_name'].unique().tolist()
# Out:
# ['Санкт-Петербург',
#  'поселок Шушары',
#  'поселок Янино-1',
#  'поселок Парголово',
#  'поселок Мурино',
#  'Ломоносов',
#  'Сертолово',
#  'Петергоф',
#  'Пушкин',
#  'деревня Кудрово',
#  'Коммунар',
#  'Колпино',
#  'поселок Красный Бор',
#  'Гатчина',
#  'деревня Федоровское',
#  'Выборг',
#  'Кронштадт',
#  'Кировск',
#  'деревня Новое Девяткино',
#  'поселок Металлострой',
#  'поселок Лебяжье',
#  'поселок Сиверский',
#  'поселок Молодцово',
#  'поселок Кузьмоловский',
#  'садовое товарищество Новая Ропша',
#  'Павловск',
#  'деревня Пикколово',
#  'Всеволожск',
#  'Волхов',
#  'Кингисепп',
#  'Приозерск',
#  'Сестрорецк',
#  'деревня Куттузи',
#  'поселок Аннино',
#  'поселок Ефимовский',
#  'поселок Плодовое',
#  'деревня Заклинье',
#  'поселок Торковичи',
#  'поселок Первомайское',
#  'Красное Село',
#  'поселок Понтонный',
#  'Сясьстрой',
#  'деревня Старая',
#  'деревня Лесколово',
#  'поселок Новый Свет',
#  'Сланцы',
#  'село Путилово',
#  'Ивангород',
#  'Мурино',
# ...

# %%
# check
data.locality_name.nunique()
# Out:
# 322

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />хорошая работа по избавлению от неявных дубликатов

# %% [markdown]
# #### Устраним редкие и выбивающиеся значения

# %%
data['ceiling_height'].unique()
# Out:
# array([  2.7 ,    nan,   3.03,   2.5 ,   2.67,   2.56,   3.05,   2.75,
#          2.6 ,   2.9 ,   2.8 ,   2.55,   3.  ,   2.65,   3.2 ,   2.61,
#          3.25,   3.45,   2.77,   2.85,   2.64,   2.57,   4.15,   3.5 ,
#          3.3 ,   2.71,   4.  ,   2.47,   2.73,   2.84,   3.1 ,   2.34,
#          3.4 ,   3.06,   2.72,   2.54,   2.51,   2.78,   2.76,  25.  ,
#          2.58,   3.7 ,   2.52,   5.2 ,   2.87,   2.66,   2.59,   2.  ,
#          2.45,   3.6 ,   2.92,   3.11,   3.13,   3.8 ,   3.15,   3.55,
#          3.16,   3.62,   3.12,   2.53,   2.74,   2.96,   2.46,   5.3 ,
#          5.  ,   2.79,   2.95,   4.06,   2.94,   3.82,   3.54,   3.53,
#          2.83,   4.7 ,   2.4 ,   3.38,   3.01,   5.6 ,   3.65,   3.9 ,
#          3.18,   3.35,   2.3 ,   3.57,   2.48,   2.62,   2.82,   3.98,
#          2.63,   3.83,   3.52,   3.95,   3.75,   2.88,   3.67,   3.87,
#          3.66,   3.85,   3.86,   4.19,   3.24,   4.8 ,   4.5 ,   4.2 ,
# ...

# %% [markdown]
# У нас есть некоторые анмоальные значения , попытаемся их исправить.Вероятнее всего пользователь ошибся при заполнении.

# %%
data.loc[data['ceiling_height']>13, 'ceiling_height'] /= 10
data.drop(data[data['ceiling_height'] > 5].index, inplace=True)
data.drop(data[data['ceiling_height'] < 1.7].index, inplace=True)

data['ceiling_height'].unique()
# Out:
# array([2.7 ,  nan, 3.03, 2.5 , 2.67, 2.56, 3.05, 2.75, 2.6 , 2.9 , 2.8 ,
#        2.55, 3.  , 2.65, 3.2 , 2.61, 3.25, 3.45, 2.77, 2.85, 2.64, 2.57,
#        4.15, 3.5 , 3.3 , 2.71, 4.  , 2.47, 2.73, 2.84, 3.1 , 2.34, 3.4 ,
#        3.06, 2.72, 2.54, 2.51, 2.78, 2.76, 2.58, 3.7 , 2.52, 2.87, 2.66,
#        2.59, 2.  , 2.45, 3.6 , 2.92, 3.11, 3.13, 3.8 , 3.15, 3.55, 3.16,
#        3.62, 3.12, 2.53, 2.74, 2.96, 2.46, 5.  , 2.79, 2.95, 4.06, 2.94,
#        3.82, 3.54, 3.53, 2.83, 4.7 , 2.4 , 3.38, 3.01, 3.65, 3.9 , 3.18,
#        3.35, 2.3 , 3.57, 2.48, 2.62, 2.82, 3.98, 2.63, 3.83, 3.52, 3.95,
#        3.75, 2.88, 3.67, 3.87, 3.66, 3.85, 3.86, 4.19, 3.24, 4.8 , 4.5 ,
#        4.2 , 3.36, 3.08, 3.68, 3.07, 3.37, 3.09, 3.26, 3.34, 2.81, 3.44,
#        2.97, 3.14, 4.37, 2.68, 3.22, 3.27, 4.1 , 2.93, 3.46, 3.47, 3.33,
#        3.63, 3.32, 2.98, 2.86, 3.17, 4.4 , 3.28, 3.04, 4.45, 3.84, 3.23,
#        3.02, 3.21, 3.43, 3.78, 4.3 , 3.39, 2.69, 3.31, 4.65, 3.56, 2.2 ,
# ...

# %%
data.shape[0]
# Out:
# 23549

# %%
data.ceiling_height.hist(figsize =(12, 4), bins=50);
plt.title('Высота полков');
plt.xlabel('Высота потолков (м²)');
plt.ylabel('Количество объявлений');

# %%
#Так как занчений меньше 2 метров не так много , можем отбросить их, так же после примерно 3.3 метров количество объявлений
#стремится к нулю
data.drop(data[data['ceiling_height'] > 3.3].index, inplace=True)
data.drop(data[data['ceiling_height'] < 2.4].index, inplace=True)
data.ceiling_height.hist(figsize =(12, 4), bins=50);
plt.title('Высота полков');
plt.xlabel('Высота потолков (м²)');
plt.ylabel('Количество объявлений');

# %%
data.shape[0]
# Out:
# 22959

# %% [markdown]
# Исправили аномальные значения в стобце 'ceiling_height'

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит поправить код, аномалии стали больше
#
#         data.loc[data['ceiling_height']==20, 'ceiling_height'] *= 10

# %% [markdown]
# В столбце общая площадь есть аномальные значения, попробуем их исправить

# %%
data['total_area'].describe()
# Out:
# count    22959.000000
# mean        58.793055
# std         32.151676
# min         12.000000
# 25%         40.000000
# 50%         51.100000
# 75%         68.000000
# max        900.000000
# Name: total_area, dtype: float64

# %%
data.loc[data['total_area']>200, 'total_area'] /= 10

data['total_area'].describe()
# Out:
# count    22959.000000
# mean        57.142146
# std         25.560565
# min         12.000000
# 25%         39.700000
# 50%         51.000000
# 75%         67.500000
# max        200.000000
# Name: total_area, dtype: float64

# %% [markdown]
# Исправим аномалии в столбце 'rooms'

# %%
data.rooms.hist(figsize =(12, 4), bins=50);

# %%
#комнаты с нулем достаточно странные данные , избавимся от них
data.drop(data[data['rooms'] > 6].index, inplace=True)
data.drop(data[data['rooms'] < 1].index, inplace=True)

# %% [markdown]
# Исследуем аномалии в общей площади

# %%
data.hist('total_area', figsize = (12,4));
plt.title('Общая площадь');

# %%
# check
data.shape[0]
# Out:
# 22713

# %%
data.drop(data[data['total_area'] > 120].index, inplace=True)
data.drop(data[data['total_area'] < 20].index, inplace=True)
data.hist('total_area', figsize = (12,4));
plt.title('Общая площадь');

# %% [markdown]
# Изучим аномалии цены.

# %%
data.hist('last_price', figsize = (12,4));
plt.title('Стоимость квартир');

# %%
# check
data.shape[0]
# Out:
# 22015

# %%
data.drop(data[data['last_price'] > 30000000].index, inplace=True)
data.drop(data[data['last_price'] < 200000].index, inplace=True)
data.hist('last_price', figsize = (12,4));
plt.title('Стоимость квартир');

# %% [markdown]
# Сколько дней продавилсь квартиры.

# %%
data.hist('days_exposition', figsize = (12,4));

# %%
# check
data.shape[0]
# Out:
# 21914

# %%
data.drop(data[data['days_exposition'] > 1100].index, inplace=True)
data.hist('days_exposition', figsize = (12,4));

# %% [markdown]
# Жилая площадь.

# %%
data.hist('living_area', figsize = (12,4), range = (30, 80));
data.hist('living_area', figsize = (12,4), range = (0, 15));

# %%
# check
data.shape[0]
# Out:
# 21786

# %%
data.drop(data[data['living_area'] > 70].index, inplace=True)
data.drop(data[data['living_area'] <= 12].index, inplace=True)

data.hist('living_area', figsize = (12,4));

# %% [markdown]
# Площаль кухни

# %%
data.hist('kitchen_area', figsize = (12,4));

# %%
# check
data.shape[0]
# Out:
# 21398

# %%
# check
data.hist(column = 'kitchen_area', bins = 15, figsize = (15,3), range = (0,9));

# %%
data.drop(data[data['kitchen_area'] < 5].index, inplace=True)
# data.hist('kitchen_area', figsize = (12,4));

# %%
# check
data.hist(column = 'kitchen_area', bins = 15, figsize = (15,3), range = (0,9));

# %%
# check
data.shape[0]
# Out:
# 21302

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит использовать больше гистограмм и в разных масштабах для корректной фильтрации данных
#
#         data.drop(data[data['kitchen_area'] < 8].index, inplace=True)
#
# Мы удалили нормальные значения площади кухни равной от 5 до 8 кв. метров, а это около 7000 записей

# %% [markdown]
# #### check gap

# %%
# check
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21302 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          21302 non-null  int64
#  1   last_price            21302 non-null  int64
#  2   total_area            21302 non-null  float64
#  3   first_day_exposition  21302 non-null  datetime64[ns]
#  4   rooms                 21302 non-null  int64
#  5   ceiling_height        12896 non-null  float64
#  6   floors_total          21302 non-null  int64
#  7   living_area           19602 non-null  float64
#  8   floor                 21302 non-null  int64
#  9   is_apartment          21302 non-null  object
#  10  studio                21302 non-null  bool
#  11  open_plan             21302 non-null  bool
#  12  kitchen_area          19453 non-null  float64
#  13  balcony               21302 non-null  int64
#  14  locality_name         21302 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __проверим какие аномалии остались__ таблица ниже

# %%
# check

# Показатели о кол-ве объявлений в датасете, минимальных и максимальных значениях 
# в выбранных параметрах о продаже квартир
# сырые данные

(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area',
          'floor', 'floors_total']]
    .apply (['count', 'min', 'max'])   
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_5d19c_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5d19c_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_5d19c_row0_col0" class="data row0 col0" >21,302.00</td>
#                         <td id="T_5d19c_row0_col1" class="data row0 col1" >21,302.00</td>
# ...

# %%
# check
data.hist(column = 'days_exposition', bins = 50, figsize = (15,3), range = (0,5));

data.hist(column = 'days_exposition', bins = 50, figsize = (15,3), range = (0,5))
plt.ylim(0, 40);

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />остались аномалии и редкости (в т.ч. и хвосты) в колонках:
#
#
#
#         'days_exposition', в минимальных значениях
#         'floors_total' - все здания выше 35-го этажа
#
# стоит учесть наличие пропусков при фильтрации данных

# %% [markdown]
# <div class="alert alert-dang er">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />остались аномалии и редкости (в т.ч. и хвосты) в колонках:
#
#         'rooms', 'living_area',  'kitchen_area' - длинные правые хвосты ...
#
#         'ceiling_height', 'days_exposition', в минимальных значениях
#
# стоит учесть наличие пропусков при фильтрации данных

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />остались аномалии и редкости (в т.ч. и хвосты) в колонках:
#
#         'rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area', 'floors_total'
#
# стоит учесть наличие пропусков при фильтрации данных

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Для выполнения пункта 2.4. существует два подхода
#
# Можно механически бороться с выбросами, ...
#
# основная проблема такого подхода — не учитывается неоднородность нашей выборки: у нас здесь и малые поселки, и вторая столица страны, и исторический фонд и массовая застройка, и однушки и довольно большое кол-во многокомнатных квартир, или наоборот одна две квартиры с количеством комнат больше 7-ми ...
#
#
#
# если бы у нас в таблице были бы только однокомнатные квартиры из определенного района массовой застройки, тогда да, мы бы боролись с выбросами традиционными способами, при нашем многообразии населенных пунктов, многокомнатности такие подходы не работают... т.е. они работают, но это усложнит наш проект — придется разбить и объединить записи нашей таблицы по нескольким параметрам (кол-во комнат, район, и т.д.), а затем только выполнять все остальные пункты на каждой отдельной выборке
#
# Остается другой подход — убираем редкие значения и следим за количеством потерь...
#
# Для выборки из 23-х тысяч значений, несколько записей со стоимостью квадратного метра выше 1-го млн. руб., довольно редкое явление
#
# Хороший пример, высота потолков, которую мы отрезаем по нижней и верхней планке, это скорее аномальные записи, посмотрим на другой аспект — на редкости: кол-во комнат
#
# __т.е. мы не говорим о том, что квартир с кол-ом комнат выше 7 не бывает, мы говорим, что для нашего исследования это редкие выбивающиеся из общей картины уникальные объекты, по которым необходимо проводить отдельную работу ...__
#
# подобным образом рассматриваем и остальные параметры
#
# наши помощники
#
# 1. гистограммы, с хорошим масштабом
# 2. метод describe() или облегченная версия, пример выше
# 3. метод value_counts()
#
# плюс жизненный опыт

# %%
# check
data.rooms.value_counts().to_frame()
# Out:
#    rooms
# 1   7707
# 2   7626
# 3   5233
# 4    681
# 5     52
# 6      3

# %%
# check
data.living_area.hist(bins = 150, figsize = (15,3));

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />т.е. все квартиры менее 10-ти и более 120-ти квадратных метров можно считать редкостями

# %%
# check
data.living_area.hist(bins = 150, figsize = (15,3), range = (100,400));

# %%
# check
data.living_area.hist(bins = 15, figsize = (15,3), range = (100,400));

# %%
# check
data.living_area.hist(bins = 10, figsize = (15,3), range = (0,15));

# %% [markdown]
# <div class="alert alert-dang er">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Осталось выполнить пункт 2.4 из брифа проекта
#
# 2.4.	Найдите и устраните редкие и выбивающиеся значения.
#
# __Критичный уровень потерь записей на этапе предобработки составляет 10%, оптимальный 5%__

# %%
# check

# Значения параметров объектов недвижимости на разных квантилях

(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  
        'kitchen_area', 'floor',   'floors_total']]
    .quantile([0.0012, 0.01, .5, .99, .9988]) # выбираем размах в 0,9976 квантилей 
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_9f249_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9f249_level0_row0" class="row_heading level0 row0" >0.0012</th>
#                         <td id="T_9f249_row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_9f249_row0_col1" class="data row0 col1" >22.00</td>
# ...

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Квантили что это такое
#
# https://fin-accounting.ru/cfa/l1/quantitative/cfa-quartiles-quintiles-deciles-percentiles?ysclid=l7gy2kky4i156375632
#
# они помогают увидеть редкости и аномалии в данных

# %% [markdown]
# ### Посчитайте и добавьте в таблицу новые столбцы

# %% [markdown]
# Добавим в таблицу новый столбце, который будет обозначать цену одного квадратного метра

# %%
data['price_square'] = data['last_price'] / data['total_area']
print(data['price_square'])
# Out:
# 0        120370.370370
# 1         82920.792079
# 2         92785.714286
# 4        100000.000000
# 5         95065.789474
#              ...
# 23693     73717.948718
# 23695     52542.372881
# 23696     44091.710758
# 23697    149511.400651
# 23698     41795.665635
# Name: price_square, Length: 21302, dtype: float64

# %% [markdown]
# Добавим столбцем день недели публикации

# %%
data['weekday']=data['first_day_exposition'].dt.weekday.astype('str').map({'0': 'Пн', '1': 'Вт', 
'2': 'Ср', '3': 'Чт', '4': 'Пт', '5':'Сб', '6': 'Вс'})
print(data['weekday'])
# Out:
# 0        Чт
# 1        Вт
# 2        Чт
# 4        Вт
# 5        Пн
#          ..
# 23693    Пт
# 23695    Пн
# 23696    Вс
# 23697    Вт
# 23698    Пт
# Name: weekday, Length: 21302, dtype: object

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Для красоты («продаваемости») всего проекта не стоит выходить за видимую ширину тетради юпитер ноутбука, коллеги ценят удобство прочтения кода. Широкие строки кода рекомендуется — делить <a href="https://qastack.ru/programming/53162/how-can-i-do-a-line-break-line-continuation-in-python">Перенос длинных строк кода</a>.
#
# </div>

# %% [markdown]
# Добавим столбец месяц публикации объявления

# %%
data['month']=data['first_day_exposition'].dt.month.astype('str').map({'1': 'Янв', '2': 'Фев', '3': 'Мар', '4': 'Апр', '5': 'Май', '6': 'Июнь', '7': 'Июль', '8': 'Авг', '9': 'Сен', '10': 'Окт', '11': 'Ноя', '12': 'Дек'})
print(data['month'])
# Out:
# 0         Мар
# 1         Дек
# 2         Авг
# 4        Июнь
# 5         Сен
#          ...
# 23693     Авг
# 23695     Янв
# 23696     Фев
# 23697     Мар
# 23698    Июль
# Name: month, Length: 21302, dtype: object

# %% [markdown]
# Добавим год публикации объявления

# %%
data['year']= data['first_day_exposition'].dt.year
print(data['year'])
# Out:
# 0        2019
# 1        2018
# 2        2015
# 4        2018
# 5        2018
#          ...
# 23693    2016
# 23695    2018
# 23696    2018
# 23697    2017
# 23698    2017
# Name: year, Length: 21302, dtype: int64

# %% [markdown]
# Добавим тип этажа квартиры , для этого напишем функцию

# %%
def floor_group(row):
    if row['floor'] == 1:
        return 'первый этаж'
    if row['floor'] == row['floors_total']:
        return 'последний этаж'
    return 'другой этаж'
data['floor_group']=data.apply(floor_group, axis=1)
print(data['floor_group'])
# Out:
# 0        другой этаж
# 1        первый этаж
# 2        другой этаж
# 4        другой этаж
# 5        другой этаж
#             ...
# 23693    другой этаж
# 23695    другой этаж
# 23696    первый этаж
# 23697    другой этаж
# 23698    первый этаж
# Name: floor_group, Length: 21302, dtype: object

# %% [markdown]
# Добавим столбце , который будет показывать расстояние до центра города в 'км'.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Функция хорошая, стоит учесть крайние условия: нулевые и отрицательные значения

# %%
data['cityCenters_nearest_km'] = (data['cityCenters_nearest'] / 1000).round(0)
print(data['cityCenters_nearest_km'])
# Out:
# 0        16.0
# 1        19.0
# 2        14.0
# 4         8.0
# 5         NaN
#          ...
# 23693    34.0
# 23695     NaN
# 23696     NaN
# 23697    10.0
# 23698     NaN
# Name: cityCenters_nearest_km, Length: 21302, dtype: float64

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> данные добавлены корректно, молодец

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# #### Изучим некоторые параметры

# %%
data.hist('total_area', bins =  50, figsize = (12, 4));
plt.title('Площадь квартир', size=20);
plt.xlabel('Площадь (м²)');
plt.ylabel('Количество квартир (шт)');

# %% [markdown]
# Можем заметить , что уже после отметки 100 значения стремятся к нулю.

# %% [markdown]
# Жилая площадь

# %%
data.hist('living_area', bins=60, figsize=(12, 4));
plt.title('Жилая площадь', size = 20);
plt.xlabel('Площадь (м²)');
plt.ylabel('Количество квартир (шт)');

# %% [markdown]
# Отбросим значения после 60 , так как они приближенны к нулю

# %%
data.drop(data[data['living_area'] > 60].index , inplace=True)
data.hist('living_area', bins=60, figsize = (12, 4));
plt.title('Жилая площадь', size = 20);
plt.xlabel('Площадь (м²)');
plt.ylabel('Количество квартир (шт)');

# %% [markdown]
# Площадь кухни

# %%
data.hist('kitchen_area', bins=60, figsize=(12,4));
plt.title('Площадь кухни', size = 20);
plt.xlabel('Площадь (м²)');
plt.ylabel('Количество квартир (шт)');

# %% [markdown]
# Посмотрим на графики рассеивания этих площадей .

# %%
price_pivot_area = data.pivot_table(index='last_price', values=([
    'total_area', 'living_area', 'kitchen_area']), aggfunc='median')
price_pivot_area = price_pivot_area.reset_index()
# Посмотрим на диаграммы рассеяния для столбцов 'total_area', 'living_area', 'kitchen_area'.
for row in ['total_area', 'living_area', 'kitchen_area']:
    sns.relplot(data=price_pivot_area, x='last_price', y=row, kind='scatter')

# %% [markdown]
# Можем видеть зависимость что чем больше площадь , тем выше и цена на квартиру.

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Хорошие графики, можно изменить размер у графиков (увеличить ширину)
#
# Подписи осей на графиках и название добавят ясности и читабельности.
# Это важные элементы любой визуализации. Как добавить подписи и названия, смотри [здесь](https://pyprog.pro/mpl/mpl_axis_signatures.html) и [там](https://pyprog.pro/mpl/mpl_title.html), и
#
# [тут](https://proproprogs.ru/modules/matplotlib-razmeshchaem-standartnye-tekstovye-elementy-na-grafike?ysclid=l6agtioc6f299002507)

# %% [markdown]
# Цена объекта

# %%
data.hist('last_price', bins=150, figsize = (12, 4));
plt.title('Цена квартир при снятии с продажи', size= 17);
plt.xlabel('Цена');
plt.ylabel('Количество квартир (шт)');

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера </b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#
#
# Слишком жесткие четыре условия для фильтрации выборки, особенно для Питера и его исторической части, стоит посмотреть на гистограмму параметра, чтобы определить, где начинаются редкие значения
#
# Потеряно около 27% данных, стоит настроить условия фильтрации, чтобы уложиться в 10%
#
# Самое главное, весь код фильтрации стоит перенести в п.2.4, сначала чистим, затем фиксируем результаты исследования для отчета

# %%
# check

# Показатели о кол-ве объявлений в датасете, минимальных и максимальных значениях 
# в выбранных параметрах о продаже квартир

(
    data[['rooms', 'total_area', 'ceiling_height', 'days_exposition', 'last_price', 'living_area',  'kitchen_area',
          'floor', 'floors_total']]
    .apply (['count', 'min', 'max'])   
    .style.format("{:,.2f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_1b70f_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >rooms</th>        <th class="col_heading level0 col1" >total_area</th>        <th class="col_heading level0 col2" >ceiling_height</th>        <th class="col_heading level0 col3" >days_exposition</th>        <th class="col_heading level0 col4" >last_price</th>        <th class="col_heading level0 col5" >living_area</th>        <th class="col_heading level0 col6" >kitchen_area</th>        <th class="col_heading level0 col7" >floor</th>        <th class="col_heading level0 col8" >floors_total</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1b70f_level0_row0" class="row_heading level0 row0" >count</th>
#                         <td id="T_1b70f_row0_col0" class="data row0 col0" >20,857.00</td>
#                         <td id="T_1b70f_row0_col1" class="data row0 col1" >20,857.00</td>
# ...

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />остались аномалии и редкости (в т.ч. и хвосты) в колонках:
#
#         'total_area', 'ceiling_height', 'days_exposition', 'living_area',  'kitchen_area', 'floors_total'
#
# стоит учесть наличие пропусков при фильтрации данных и обратить внимание на минимальные значения в выборке

# %% [markdown]
# Количество комнат

# %%
data.hist('rooms', bins=20, figsize = (12, 4));
plt.title('Количество комнат', size = 18);
plt.xlabel('Число комнат (шт)');
plt.ylabel('Количество квартир (шт)');

# %% [markdown]
# Данные с 0 комнатой выглядят страно , удалим их

# %%
data.drop(data[data['rooms'] < 1].index , inplace=True)
data.hist('rooms', bins=20, figsize = (12, 4));

plt.title('Количество комнат', size = 18);
plt.xlabel('Число комнат (шт)');
plt.ylabel('Количество квартир (шт)');

# %% [markdown]
# Высота потолков

# %%
data.hist('ceiling_height', bins=200, figsize = (12, 4));
plt.title('Высота потолков');
plt.xlabel('Высота потолков');
plt.ylabel('Количество квартир');

# %% [markdown]
# Так как мы уже ранее исправили аномальнии значения, пик высоты потолков примерно 2-3 метра

# %% [markdown]
# Этаж квартиры

# %%
data.hist('floor', bins=200, figsize= (12, 4));
plt.title('Этаж квартиры');
plt.xlabel('Этаж');
plt.ylabel('Количество квартир');

# %% [markdown]
# Можем заметить , что большинство квартир в объявлениях находятся на 2 этаже.

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит изменить параметры отображения гистограммы (добавить корзин), сейчас трудно определить границу резкого снижения кол-ва объявлений, или на 4-ке, или на 5-ке, или на 6-ке ... и поправить вывод
#
#         Можем заметить , что большинство квартир в объявлениях находятся на 3-6 этажах
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Общее кол-во этажей

# %%
data.hist('floors_total', bins=150, figsize = (12, 4));
plt.title('Общее количество этажей');
plt.xlabel('Всего этажей');
plt.ylabel('Количество квартир');

# %% [markdown]
# Можем заменить , что в основном дома имеют примерно 5 этажей

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Стоит изменить параметры отображения гистограммы (добавить корзин), сейчас может показаться, что
#
#         Можем заменить , что в основном дома имеют примерно 5 этажей

# %% [markdown]
# Тип этажа квартиры.

# %%
floors=data.pivot_table(index='floor_group', values='last_price' , aggfunc='count')
floors.plot(kind='bar', figsize=(5, 7));
plt.title('Тип этажа квартиры');
plt.xlabel('Тип этажа');
plt.ylabel('Количество квартир');

# %% [markdown]
# Можем заметить что в основм кваритры находяться не на первом и последнем этаже.

# %% [markdown]
# Расстояние до центра города (м)

# %%
data.hist('cityCenters_nearest', bins=100, figsize=(12, 4));
plt.title('Расстояние до центра города');
plt.ylabel('Количество квартир');
plt.xlabel('Расстоние (м)');

# %% [markdown]
# Пик знаечний находитьв диапазоне 11к-13к и 17к метров

# %% [markdown]
# Расстояние до ближайшего аэропорта

# %%
data.hist('airports_nearest', bins=100, figsize=(12, 4));
plt.title('Расстояние до ближайшего аэропорта');
plt.ylabel('Количество квартир');
plt.xlabel('Расстоние (м)');

# %% [markdown]
# Пик знаечний находится на примерно 17000 м

# %% [markdown]
# Расстояние до ближайшего парка

# %%
data.hist('parks_nearest', bins=150, figsize=(12, 4));
plt.title('Расстояние до ближайшего парка');
plt.ylabel('Количество квартир');
plt.xlabel('Расстоние (м)');

# %% [markdown]
# Пик значений находится в промежутке 400-500

# %% [markdown]
# День публикации объявления.

# %%
weekday = data.pivot_table(index='weekday', values='last_price', aggfunc='count')
weekday.plot(kind='bar', figsize=(12, 4));
plt.title('День публикации объявления');
plt.ylabel('Количество квартир');
plt.xlabel('День недели');

# %% [markdown]
# Можем заметить , что в выходные дни продажи падают , а во вт, ср и чт наблюдается пик продаж

# %% [markdown]
# Месяц публикации объявления

# %%
month = data.pivot_table(index='month', values='last_price', aggfunc='count')
month.plot(kind='bar', figsize=(12, 4))
plt.title('Месяц публикации объявления');
plt.xlabel('Месяц');
plt.ylabel('Количество квартир');

# %% [markdown]
# Пик продаж наблюдается в феврале.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __Интересно, почему февраль (самый короткий месяц) опережает все месяцы — ?__

# %% [markdown]
# Год публикации объявления

# %%
year = data.pivot_table(index='year', values='last_price', aggfunc='count')
year.plot(kind='bar', figsize=(12, 4));
plt.title('Год публикации объявления');
plt.xlabel('Год');
plt.ylabel('Количество квартир');

# %% [markdown]
# Пик продаж в 2017, 2018 годах.

# %% [markdown]
# <div class="alert alert-da ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Осталось добавить три гистограммы из 14-ти обязательных
#
# Шаг 4. Проведите исследовательский анализ данных:
# 1.	Изучите следующие параметры объектов:
#     +	общая площадь;
#     +	жилая площадь;
#     +	площадь кухни;
#     +	цена объекта;
#     +	количество комнат;
#     +	высота потолков;
#     +	этаж квартиры;
#     +	тип этажа квартиры («первый», «последний», «другой»);
#     +	общее количество этажей в доме;
#     +	расстояние до центра города в метрах;
#     +	расстояние до ближайшего аэропорта;
#     +	расстояние до ближайшего парка;
#     +	день и месяц публикации объявления.
#
#
# __Постройте отдельные гистограммы для каждого из этих параметров.__ Опишите все ваши наблюдения по параметрам в ячейке с типом markdown.

# %% [markdown]
# #### Изучим как быстро продавались квартиры

# %%
#Найдем среднию и медиану
print(data['days_exposition'].mean().round(0))
print(data['days_exposition'].median().round(0))
# Out:
# 166.0
# 90.0

# %%
data.hist('days_exposition', bins=200, figsize =(12, 4));
plt.title('Сколько дней было размещенно объявление');
plt.xlabel('Количество дней');
plt.ylabel('Количество квартир');

# %% [markdown]
# Пик продаже наступает где-то на 45 день, после 800 дней продаже становяться достаточно редкие, после 1200 дней продаж почти нет.

# %%
data.drop(data[data['days_exposition']>1200].index , inplace=True)
data.hist('days_exposition', bins=200, figsize = (12, 4));
plt.title('Сколько дней было размещенно объявление');
plt.xlabel('Количество дней');
plt.ylabel('Количество квартир');

# %%
#Посчитаем среднее и медиану заново
print(data['days_exposition'].mean().round(0))
print(data['days_exposition'].median().round(0))
# Out:
# 166.0
# 90.0

# %% [markdown]
# Как видим половина квартир продается за 172 дней , а среднее время продажи составляет 92 дня , уже дальше можем наблюдать спад продаж.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Выборка data['days_exposition'] имеет длинный правый хвост, не стоит обрезать подобный хвост на таких значениях, оптимально ориентироваться на значения 0,99 квантиля, это где-то 1200 дней ...
#
#         data.drop(data[data['days_exposition']>300].index , inplace=True)

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит пересчитать статистики скорости продажи после восстановления записей

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# __Интересно посмотреть на изменение средней  скорости продаж по годам__

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Не исследованы моды в 'days_exposition' и как они влияют на скорость продажи, подсказка на что смотреть
#
# [Условия размещения объявлений](https://yandex.ru/support/realty/owner/home/add-ads-housing.html)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />   Для определения быстрых и долгих продаж оптимальнее ориентироваться на 25-тый и 75-тый квантили

# %% [markdown]
# #### Определим какие факторы влияют на продажи

# %% [markdown]
# Зависимость цены от общей площади квартиры

# %%
print(data['last_price'].corr(data['total_area']))
data.plot(x='total_area', kind='scatter', y='last_price', alpha=0.2);
plt.title('Зависимость цены от площади квартиры', size=17);
plt.xlabel('Площадь, м²');
plt.ylabel('Цена, млн руб.');
# Out:
# 0.6944283676798774

# %% [markdown]
# Можем видеть , что основные данные находяться у нас в диапазоне от 30-50 кв.м и стоимости 3-4 млн

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />  Можно попробовать настроить вид точечных графиков
#
# [5.2. Scatter - график разброса (точки)](https://pyprog.pro/mpl/mpl_scatter.html?ysclid=l65k3vmmqd649359421)
#
# Примеры расчета коэф. корреляции и не только
#
# [Исследуем отношение между переменными](https://dfedorov.spb.ru/pandas/downey/%D0%98%D1%81%D1%81%D0%BB%D0%B5%D0%B4%D1%83%D0%B5%D0%BC%20%D0%BE%D1%82%D0%BD%D0%BE%D1%88%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BC%D0%B5%D0%B6%D0%B4%D1%83%20%D0%BF%D0%B5%D1%80%D0%B5%D0%BC%D0%B5%D0%BD%D0%BD%D1%8B%D0%BC%D0%B8.html?ysclid=l9ev0utyg728177057)

# %% [markdown]
# Зависимость цены от жилой площади

# %%
print(data['last_price'].corr(data['rooms']).round(2))
data.plot(x='rooms', y='last_price', kind='scatter', alpha=0.05);
plt.title('Зависимость цены от числа комнат', size=14);
plt.xlabel('Число комнат, комн.');
plt.ylabel('Цена, млн руб.');
# Out:
# 0.37

# %% [markdown]
# Основные данные у нас лежать в диапазоне 17-19 кв.м и стоимости 2.5-4 млн

# %% [markdown]
# Зависимость цены от площади кухни

# %%
print(data['last_price'].corr(data['kitchen_area']).round(2))
data.plot(x='kitchen_area', y='last_price', kind='scatter', alpha=0.05);
plt.title('Зависимость цены от числа комнат', size=14);
plt.xlabel('Число комнат, комн.');
plt.ylabel('Цена, млн руб.');
# Out:
# 0.57

# %% [markdown]
# В основном данные находятся в диапазоне 10-16 и стоимостью примерно 3.5-5.5 млн

# %% [markdown]
# Зависимость цены от количества комнат

# %%
print(data['last_price'].corr(data['rooms']).round(2))
data.plot(x='rooms', y='last_price', kind='scatter', alpha=0.05);
plt.title('Зависимость цены от числа комнат', size=14);
plt.xlabel('Число комнат, комн.');
plt.ylabel('Цена, млн руб.');
# Out:
# 0.37

# %% [markdown]
# Основные данные находятся в диапазоне 1-3 комнат.Зависимость достаточно слабая.

# %% [markdown]
# Зависимость продаж по типу этажей

# %%
floors=data.pivot_table(index='floor_group', values='last_price', aggfunc='count')
ax=floors.plot(kind='bar', figsize=(12, 4))
plt.ylim(bottom=1000)
ax.legend_.remove()
plt.title('Зависимость цены от этажа, на котором расположена квартира', size=17);
plt.xlabel('Этаж');
plt.ylabel('Количество квартир, шт.');

# %% [markdown]
# Люди больше покупают квартиру не на первом и не последнем этаже.

# %% [markdown]
# Зависимость продаж от дня недели , месяца и года.

# %%
weekday = data.pivot_table(index='weekday', values='last_price', aggfunc= ('mean'))
weekday.plot(kind='bar', figsize=(17, 8));
plt.title('Средняя стоимость квартир по дню недели');
plt.xlabel('День недели');
plt.ylabel('Цена');

# %% [markdown]
# Продажи стабильные в каждый день недели.

# %% [markdown]
# <div class="alert alert-dang er">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
#         floors=data.pivot_table(index='floor_group', values='last_price', aggfunc='count')
#         floors.plot(kind='bar', figsize=(5, 7))
#
#
#         weekday = data.pivot_table(index='weekday', values='last_price', aggfunc='count')
#         weekday.plot(kind='bar', figsize=(5, 7))
#
#         month = data.pivot_table(index='month', values='last_price', aggfunc='count')
#         month.plot(kind='bar', figsize=(5, 7))
#
#
# Мы рассчитали кол-во подаваемых объявлений по категориям этажей, в день недели, в месяц — это требуется сделать в п.4.1 — можно перенести графики в раздел 4.1
#
# Здесь мы рассчитываем среднюю стоимость всех квартир по дням недели, месяцам и годам

# %%
month = data.pivot_table(index='month', values='last_price', aggfunc={'mean'})
month.plot(kind='bar', figsize=(12, 4));
plt.title('Средняя стоимость квартир по месецам');
plt.xlabel('Месяц');
plt.ylabel('Цена');

# %% [markdown]
# Год

# %%
year = data.pivot_table(index='year', values='last_price', aggfunc={'mean'})
year.plot(kind='bar', figsize=(12, 4));
plt.title('Средняя стоимость квартир по годам');
plt.xlabel('Год');
plt.ylabel('Цена');
year = data.pivot_table(index='year', values='last_price', aggfunc={'count'})
year.plot(kind='bar', figsize=(12, 4));
plt.title('Количество объявлений каждый год');
plt.xlabel('Год');
plt.ylabel('Цена');

# %% [markdown]
# Можем увидеть что объявлеий в 2014 году было меньше , но средняя стоимость квартир по годам больше в 2017 и 2018 годах.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Если смотреть только на изменение цены по годам мы можем сделать некорректный вывод, что цены падали, а на самом деле цена это параметр на который влияет несколько других факторов, по этой причине можно посмотреть на основные из них:
#
# + изменение кол-ва записей — принять решение о достаточности данных для анализа и сравнения (сравнивать 136 объявлений и 8454, а возможно, что они еще и из разных локаций, не совсем корректно)
# + изменение площади, как основного параметра от которого зависит стоимость квартиры, в 2017-2018 гг. на рынок пришел массовый продавец, и средние значения упали ..., а за ней и цена
# + изменение кол-ва поданных объявлений из разных локаций, т.к. есть питерские квартиры, а есть выборгские квартиры и стоят они по разному, и в разные годы могло быть больше квартир из определенной локации
# + полнота периода для анализа, 2014 и 2019 гг. неполные, а у нас есть сезонные колебания цен, например летнее снижение цен
# + изменение доли дорогих категорий в общей выборке (средние этажи)
#
# и т.д.

# %% [markdown]
# <div class="alert alert-dan ger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Стоит дополнить  вывод об изменении цен по годам, необходимо учесть другие факторы, которые также изменяются с годами: площадь и кол-во объявлений о продаже (стоит добавить или графики, или сводные таблицы и исследовать взаимное влияние параметров)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />присвоение вместо цифровых значений наименований — месяцам, с одной стороны удобно, но с другой приводит к доп.затратам при сортировке значений в хронологическом порядке

# %% [markdown]
# <div class="alert alert-dang er">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />    Стоит добавить 4 последних графика
#
# Шаг 4. Проведите исследовательский анализ данных:
#
# 3.	Какие факторы больше всего влияют на общую (полную) стоимость объекта?
#     Изучите, зависит ли цена от:
#     +	общей площади;
#     +	жилой площади;
#     +	площади кухни;
#     +	количества комнат;
#     +	этажа, на котором расположена квартира (первый, последний, другой);
#     +	даты размещения (день недели, месяц, год).
#
# Постройте графики, которые покажут зависимость цены от указанных выше параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы.
#
#
#
# Советы по графикам:
#
# + зависимость параметров (от площади, удалённости от центра) оптимальнее рассматривать на точечных графиках (тип scatter),
# + динамику на линейных (это про сравнение цен за год, месяц, день недели), — стоит сгруппировать значения и рассчитать среднее или медианное значение
# + сравнение цен на барах (для сравнение средней стоимости квартиры по трем категориям), — стоит сгруппировать значения и рассчитать среднее или медианное значение

# %% [markdown]
# #### Топ 10 населенных пунктов с наибольшим числом объявлений.

# %%
top = (data.groupby('locality_name')['price_square'].agg(['count', 'mean'])).sort_values(by='count', ascending=False).head(10).round(0)
display(top)
top.plot(kind='barh',figsize=(12, 4));
plt.xlabel('Наименование населенного пункта');
# Out:
#                    count      mean
# locality_name
# Санкт-Петербург    13399  109375.0
# поселок Мурино       513   84849.0
# поселок Шушары       416   77920.0
# Всеволожск           378   68535.0
# Пушкин               330  101882.0
# Колпино              326   75505.0
# поселок Парголово    310   90132.0
# Гатчина              297   68819.0
# деревня Кудрово      274   92090.0
# Выборг               210   57803.0

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />      Можно развернуть график
#
#      kind='barh'

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />ТОП-10 рассчитан корректно

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Недостаточно найти числа, стоит их показать красиво, удобно и наглядно, чтобы одного взгляда хватило, где самые самые, а где подешевле 📊

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [Постер поможет выбирать вид графиков](https://www.notion.so/6c5ae8ceb8b5411e907c93c9b5e6a44e)

# %% [markdown]
# <div class="alert alert-warning", style="border:solid coral 3px; padding: 20px">
# <font size="4", color = "DimGrey"><b>⚠️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> на проектах стоит снижать размерность выводимой информации, где не требуется максимальная точность, до одного или двух знаков после запятой
#
#         Пушкин               273  100023.576354
#         Гатчина              248   69148.376512
#         деревня Кудрово      224   92816.466676
#         Выборг               186   58320.953775

# %% [markdown]
# #### Посчитаем средниюю цену одного кв.м в этих населеных пунктах

# %%
print(top['mean'].mean())
# Out:
# 82691.0

# %% [markdown]
# Выделим населенные пункты с самой высокой и низкой стоимостью квадратного метра.

# %%
print(top.sort_values(by='mean', ascending=False).head(2))
print(top.sort_values(by='mean', ascending=False).tail(2))
# Out:
#                  count      mean
# locality_name
# Санкт-Петербург  13399  109375.0
# Пушкин             330  101882.0
#                count     mean
# locality_name
# Всеволожск       378  68535.0
# Выборг           210  57803.0

# %% [markdown]
# Узнаем среднию цену за км в Санкт-Петербурге

# %%
spb=data.query('locality_name == "Санкт-Петербург"')
spb.reset_index(drop=True, inplace=True)
 
# На счет физического смысла , я хотел найти среднюю стоимость каждого киллометра , но у меня почему стало вмето значения писать inf

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Можешь объяснить физический смысл показателя
#
#         mean_spb_km = spb['last_price'] / spb['cityCenters_nearest_km']
#
# что это такое и что он отражает

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера в2</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Это ошибочный показатель
#
#         mean_spb_km = spb['last_price'] / spb['cityCenters_nearest_km']
#
# Возьмем 10 условных квартир равной стоимостью 10 млн. руб., но расположенных на первом, втором, третьем и т.д. километрах от центра.
#
# При твоем способе подсчета если 10 млн. руб. разделить на само значение километра мы получим 10, 5, 3.33 ... млн. руб. на км., но квартиры по стоимости равны ...., а в выводе мы можем предположить, что цена падает, что будет ошибкой

# %% [markdown]
# #### Теперь найдем зависимость стоимости квартиры от расстояние до центра города

# %%
spb.dropna()
spb_hist=spb.groupby(['cityCenters_nearest_km']).agg({'last_price' : 'mean'})
spb_hist.plot(style='go', figsize = (20,5), markersize=10, grid=True);

# %% [markdown]
# Изучим данные на 20 км

# %%
spb_pivot_table = spb.pivot_table(index = 'last_price', values= 'cityCenters_nearest_km', aggfunc = 'count')
spb_pivot_table.hist(figsize = (12, 4) ,range = (15, 25));
display(spb[spb['cityCenters_nearest_km'] == 20])
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 202              15     5990000       54.00           2018-03-22      2
# 279              15     5900000       67.40           2019-01-11      3
# 452              14     7777777       75.00           2017-11-16      2
# 558              10     5200000       50.00           2015-11-06      2
# 928              11     3550000       28.00           2018-02-08      1
# 1037             13    10150000       74.00           2017-11-17      2
# 1102             20     7800000       97.30           2019-04-06      3
# 1547              5     3350000       30.60           2017-06-22      1
# 1615              9     4300000       37.00           2017-08-08      1
# 2005              6     2900000       30.70           2018-08-22      1
# 2317              0     5550000       63.00           2016-03-23      3
# 2721             12     5500000       50.00           2017-06-22      1
# ...

# %% [markdown]
# Изучим данные на 27 км.

# %%
display(spb[spb['cityCenters_nearest_km'] == 27])
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 383             13    14350000        74.0           2017-11-28      2
# 3375             6     2250000        32.0           2018-02-27      1
#
#       ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 383             3.13             5         30.0      3            0  ...
# 3375             NaN             2         16.5      2            0  ...
#
#       parks_nearest  ponds_around3000  ponds_nearest  days_exposition  \
# 383          1496.0                 0            NaN            128.0
# 3375            NaN                 0            NaN            178.0
#
#        price_square  weekday  month  year     floor_group  \
# 383   193918.918919       Вт    Ноя  2017     другой этаж
# 3375   70312.500000       Вт    Фев  2018  последний этаж
#
#       cityCenters_nearest_km
# 383                     27.0
# 3375                    27.0
#
# [2 rows x 28 columns]

# %% [markdown]
# На 27 км выбросы у нас связаны с тем что у нас всего 2 квартиры на этом участке , поэтому среднее такое и высокое

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Принимается, кол-во наблюдений важный параметр для оценки качества данных. Из двух записей одна аномалия ..., по этой причине можно отвергнуть наблюдение

# %% [markdown]
# Построим диаграмму рассеивания и узнаем от чего же зависит цена больше всего.

# %%
sns.pairplot(data[['last_price', 'total_area', 'rooms', 'cityCenters_nearest', 'living_area']])
plt.gcf().set_size_inches(12,12);

# %% [markdown]
# Цены на квартиры в Санкт-Петербурге так и по всем городам , в основном зависят от жилой площади , количества комнат ,
# жилой площади ,остальные же факоры не так сильно влияют на стоимость.

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Молодец, у тебя получилось сгруппировать и построить график изменения средней цены в зависимости от расстояния до центра

# %% [markdown]
# <div class="alert alert-da nger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Стоит изучить записи, которые привели к выбросу на 20-м км.

# %% [markdown]
# <div class="alert alert-d anger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
#
# Стоит посмотреть на количество квартир разных категорий (первый, последний, другой), которые продаются на 3-м км. и 5-ом ... и какую долю они занимают на каждом километре, чтобы объяснить пик и провал в центре
#
#
#         Стоит посмотреть на категории квартир, которые продаются на 3-м км. и 5-ом ... и какую долю они занимают на каждом километре, чтобы объяснить пик  и провал в центре

# %%
spb_hist=spb.groupby(['cityCenters_nearest_km']).agg({'last_price' : 'mean'})
spb_hist.plot(style='o-', figsize = (20,5), markersize=10, grid=True);

# %% [markdown]
# <div class="alert alert-success">
# <font size="4", color= "seagreen"><b>✔️ Комментарий ревьюера в3</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />Категорий квартир с более дешевой стоимостью намного больше на 3-м километре, чем на пятом, возможно отсюда падение и пик...
#
#
# На 18-м и 20-м примерно такая же картина
#
# возможно к этому фактору добавляются и другие

# %%
# способы группировки и сортировки информации

(
    spb
     .query('3 <= cityCenters_nearest_km <= 5')
     .groupby(['cityCenters_nearest_km', 'floor_group'])['last_price']
     .agg(['count', 'mean'])
     .style.format("{:,.0f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_9ac80_" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >mean</th>    </tr>    <tr>        <th class="index_name level0" >cityCenters_nearest_km</th>        <th class="index_name level1" >floor_group</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9ac80_level0_row0" class="row_heading level0 row0" rowspan="3">3.0</th>
#                         <th id="T_9ac80_level1_row0" class="row_heading level1 row0" >другой этаж</th>
#                         <td id="T_9ac80_row0_col0" class="data row0 col0" >107</td>
#                         <td id="T_9ac80_row0_col1" class="data row0 col1" >8,503,886</td>
#             </tr>
#             <tr>
# ...

# %%
# способы группировки и сортировки информации

(
    spb
     .query('18 <= cityCenters_nearest_km <= 20')
     .groupby(['cityCenters_nearest_km', 'floor_group'])['last_price']
     .agg(['count', 'mean'])
     .style.format("{:,.0f}")
)
# Out:
# <style  type="text/css" >
# </style><table id="T_acd0c_" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >mean</th>    </tr>    <tr>        <th class="index_name level0" >cityCenters_nearest_km</th>        <th class="index_name level1" >floor_group</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_acd0c_level0_row0" class="row_heading level0 row0" rowspan="3">18.0</th>
#                         <th id="T_acd0c_level1_row0" class="row_heading level1 row0" >другой этаж</th>
#                         <td id="T_acd0c_row0_col0" class="data row0 col0" >196</td>
#                         <td id="T_acd0c_row0_col1" class="data row0 col1" >4,832,559</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# При работе над проектов мы выполнили:
#
#     1)Предобработку данных:определили в каких столбцах есть пропуски, заполнили пропуски там где это можно, изменили типы данных где этобыло нужно, устранили неявные дубликаты, устранили редкие и выбивающие значения.
#
#     2)Добавили в таблицу новые столбцы со следующими параметрами:
#             цена одного квадратного метра;
#             день недели публикации объявления;
#             месяц публикации объявления;
#             год публикации объявления;
#             тип этажа квартиры;
#             расстояние до центра города в километрах .
#     3)Провели исследовательский анализ данных по всеми нашему датасету , а так же узнали среднюю цену одного квадратного метра в населенных пункатах с наибольшим числом объявлений, узнали среднюю стоимость одного км в Питере, узнали как стоимость зависит от расстояния до центра города.
#
# Цены на квартиры в Санкт-Петербурге так и по всем городам , в основном зависят от жилой площади , количества комнат ,
# жилой площади ,остальные же факоры не так сильно влияют на стоимость.

# %% [markdown]
# <div class="alert alert-danger">
# <font size="4"><b>❌ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br /> Технически вывод хороший, есть сравнения показателей, инсайты, анализ рынка недвижимости, молодец
#
# Осталось перепроверить итоговый вывод после исправления всех комментариев

# %% [markdown]
# <div class="alert alert-success">
# <font size="5"><b>✔️ Комментарий ревьюера</b></font>
#     <br />
#     <font size="3", color = "black">
# <br />
# Выполнил исследовательскую работу, молодец, показал хороший уровень навыков программирования
#
# Критические ❌ комментарии
#
# + настроить фильтрацию редких значений в п. 2.4
# + добавить гистограмм в п.4.1
# + пересчитать скорость продаж
# + добавить графики в п. 4.3
# + добавить график в ТОП-10
# + исследовать аномалии в п.4.5
# + перепроверить параметр в п.4.5
# + поправить итоговый вывод
#
#
# С ними важно поработать и исправить
#
# Стоит обратить внимание и на такие комментарии ⚠️
#
# Если будут вопросы про мои комментарии - задавай, если какой-то формат взаимодействия не устраивает или есть какие-то другие пожелания - пиши :)
#
# <div class="alert alert-success">
#     <font size="5"><b>Жду твой проект и твои комментарии 🤝</b></font><br />
#
# нумерация пунктов из брифа проекта, у тебя они могут быть другие

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [Обработка пропусков в данных](https://loginom.ru/blog/missing)
#
# <p> Доп. материал: методы группировки и расчета суммы, средних и т.д.
#
# [Подробное руководство по группировке и агрегированию с помощью pandas](https://dfedorov.spb.ru/pandas/%D0%9F%D0%BE%D0%B4%D1%80%D0%BE%D0%B1%D0%BD%D0%BE%D0%B5%20%D1%80%D1%83%D0%BA%D0%BE%D0%B2%D0%BE%D0%B4%D1%81%D1%82%D0%B2%D0%BE%20%D0%BF%D0%BE%20%D0%B3%D1%80%D1%83%D0%BF%D0%BF%D0%B8%D1%80%D0%BE%D0%B2%D0%BA%D0%B5%20%D0%B8%20%D0%B0%D0%B3%D1%80%D0%B5%D0%B3%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D1%8E%20%D1%81%20%D0%BF%D0%BE%D0%BC%D0%BE%D1%89%D1%8C%D1%8E%20pandas.html)
#
#  Интересная функция в библиотеке пандаса
#
# [Понимание функции transform в Pandas](https://dfedorov.spb.ru/pandas/%D0%9F%D0%BE%D0%BD%D0%B8%D0%BC%D0%B0%D0%BD%D0%B8%D0%B5%20%D1%84%D1%83%D0%BD%D0%BA%D1%86%D0%B8%D0%B8%20transform%20%D0%B2%20Pandas.html)
#
# [Как выбрать определенные столбцы из DataFrame](https://dfedorov.spb.ru/pandas/03.%20%D0%9A%D0%B0%D0%BA%20%D0%B2%D1%8B%D0%B1%D1%80%D0%B0%D1%82%D1%8C%20%D0%BF%D0%BE%D0%B4%D0%BC%D0%BD%D0%BE%D0%B6%D0%B5%D1%81%D1%82%D0%B2%D0%BE%20%D0%B8%D0%B7%20DataFrame_.html?ysclid=l9sps5lt6g576766938)
#
# [How to visualise data using histograms in Pandas](https://practicaldatascience.co.uk/data-science/how-to-visualise-data-using-histograms-in-pandas)

# %% [markdown]
# ### Бонус

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />Диаграмма рассеяния

# %%
# check
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# check
sns.pairplot(data[['last_price', 'total_area', 'rooms', 'cityCenters_nearest']])
plt.gcf().set_size_inches(12,12);

# %% [markdown]
# <div style="border:solid steelblue 3px; padding: 20px">
# <font size="4">🍕<b> Комментарий ревьюера в2</b></font>
# <br />
# <font size="3", color = "black">
# <br />
#
# [5.2. Scatter - график разброса (точки)](https://pyprog.pro/mpl/mpl_scatter.html?ysclid=l65k3vmmqd649359421)

# %%
# check
data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter',
        y='last_price' , x='total_area', alpha=0.5, subplots=True, figsize=(15,8), c = 'b', s = 4)
plt.title('Диаграмма рассеяния — Общая площадь — цена трешки')


data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter', 
        y='last_price' , x='living_area', alpha=0.5, figsize=(15,8), c = 'r', s = 4)
plt.title('Диаграмма рассеяния — Жилая площадь — цена трешки');

# %%
# check
price_pivot_area = data.pivot_table(index='last_price', values=([
    'total_area', 'living_area', 'kitchen_area']), aggfunc='median')
price_pivot_area = price_pivot_area.reset_index()
# Посмотрим на диаграммы рассеяния для столбцов 'total_area', 'living_area', 'kitchen_area'.
for row in ['total_area', 'living_area', 'kitchen_area']:
    sns.relplot(data=price_pivot_area, x='last_price', y=row, kind='scatter')

# %%
# check
data[data['rooms'] == 3].query('total_area < 201 and last_price < 25_000_000').plot(kind='scatter',
        y='living_area' , x='total_area', alpha=0.5, subplots=True, figsize=(15,8), c = 'g', s = 4)
plt.title('Диаграмма рассеяния — Общая площадь — Жилая');

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения там, где это возможно
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  устранены неявные дубликаты в названиях населённых пунктов
# - [x]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# - [x]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [x]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [x]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [x]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [x]  в каждом этапе есть промежуточные выводы
# - [x]  есть общий вывод
